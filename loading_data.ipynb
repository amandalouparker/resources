# %%
import pandas

# %%
dataframe = pandas.read_csv('GlobalInnovationIndex_Knoema.csv', index_col=0)
dataframe
# Out:
#                                                            indicator measure  \
# country
# Albania                            Global Innovation Index (average)   Score
# Albania                            Global Innovation Index (average)   Score
# Albania                            Global Innovation Index (average)   Score
# Albania                            Global Innovation Index (average)   Score
# Albania                            Global Innovation Index (average)   Score
# Albania                            Global Innovation Index (average)   Score
# Albania                            Global Innovation Index (average)   Score
# Albania                            Global Innovation Index (average)   Score
# Algeria                            Global Innovation Index (average)   Score
# Algeria                            Global Innovation Index (average)   Score
# Algeria                            Global Innovation Index (average)   Score
# ...

# %%
score = dataframe[dataframe.Date==2015].Value.copy() #returns a series
Y = pandas.DataFrame(score) #makes a series a dataframe

# %%
Y
# Out:
#                                    Value
# country
# Albania                             30.7
# Algeria                             24.4
# Angola                              26.2
# Argentina                           34.3
# Armenia                             37.3
# Australia                           55.2
# Austria                             54.1
# Azerbaijan                          30.1
# Bahrain                             37.7
# Bangladesh                          23.7
# Barbados                            42.5
# Belarus                             38.2
# Belgium                             50.9
# Bhutan                              26.1
# Bolivia, Plurinational State of     28.6
# Bosnia and Herzegovina              32.3
# Botswana                            30.5
# Brazil                              34.9
# Bulgaria                            42.2
# Burkina Faso                        28.7
# Burundi                             21.0
# Cambodia                            30.4
# ...
